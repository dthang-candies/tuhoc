# %% [markdown]
# <a href="https://colab.research.google.com/github/dthang-candies/tuhoc/blob/main/rag_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
#   File "/tmp/ipython-input-641805450.py", line 1
#     vi main.py
#        ^
# SyntaxError: invalid syntax
